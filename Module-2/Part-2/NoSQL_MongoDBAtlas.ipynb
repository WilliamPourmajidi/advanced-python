# %% [markdown]
# # Working with MongoDB Atlas in Python
# This Jupyter notebook demonstrates how to connect to a MongoDB Atlas cluster, perform CRUD operations (Create, Read, Update, Delete), and interpret the results using Python.

# %% [markdown]
# ## Step 1: Connect to MongoDB Atlas
# We use `pymongo` to connect to MongoDB Atlas. Be sure to replace your `username` and `password` with your own credentials.

# %%
# from pymongo.mongo_client import MongoClient
# from pymongo.server_api import ServerApi

import pymongo
from pymongo import MongoClient
from pymongo.server_api import ServerApi



username = "pythonic-access"
pw = "7g2JamtjhWQLyFta"

uri = f"mongodb+srv://{username}:{pw}@cluster-william.rvoxqwd.mongodb.net/?appName=cluster-william"



# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))


# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ## Step 2: Insert Documents (Create)
# We define a `recipes` collection and insert a list of documents representing meal recipes.

# %%
# Use a database and collection


# Instantiating a database and collection
db = client.myDatabase
# Collections are similar to tables in relational databases, but they are schema-less and can store documents with varying structures.
my_collection = db["recipes"]

# Recipe documents
recipe_documents = [
    {"name": "Meal#1", "ingredients": ["corn", "mayonnaise", "cotija cheese", "sour cream", "lime"], "prep_time": 39},
    {"name": "Meal#2", "ingredients": ["ground beef", "butter", "onion", "egg", "bread bun", "mushrooms"], "prep_time": 54},
    {"name": "Meal#3", "ingredients": ["potato", "tomato", "olive oil", "onion", "garlic", "paprika"], "prep_time": 80},
    {"name": "Meal#4", "ingredients": ["rice", "soy sauce", "egg", "onion", "pea", "carrot", "sesame oil"], "prep_time": 40}
]

# Drop the collection if it exists
my_collection.drop()

# Insert documents
result = my_collection.insert_many(recipe_documents)
print(f"Inserted {len(result.inserted_ids)} documents.")
# Out:
# Inserted 4 documents.

# %% [markdown]
# ## Step 3: Read Documents (Read)
# Use `.find()` to retrieve documents and display summary info for each recipe.

# %%
# Read all documents
result = my_collection.find()

for doc in result:
    print(f"{doc['name']} has {len(doc['ingredients'])} ingredients which are {doc["ingredients"]} and this meal takes {doc['prep_time']} minutes to prepare.")
# Out:
# Meal#1 has 5 ingredients which are ['corn', 'mayonnaise', 'cotija cheese', 'sour cream', 'lime'] and this meal takes 39 minutes to prepare.
# Meal#2 has 6 ingredients which are ['ground beef', 'butter', 'onion', 'egg', 'bread bun', 'mushrooms'] and this meal takes 54 minutes to prepare.
# Meal#3 has 6 ingredients which are ['potato', 'tomato', 'olive oil', 'onion', 'garlic', 'paprika'] and this meal takes 80 minutes to prepare.
# Meal#4 has 7 ingredients which are ['rice', 'soy sauce', 'egg', 'onion', 'pea', 'carrot', 'sesame oil'] and this meal takes 40 minutes to prepare.

# %% [markdown]
# ## Step 4: Find One Document
# Search for a recipe that contains a specific ingredient, like `potato`.

# %%
my_doc = my_collection.find_one({"ingredients": "potato"})
if my_doc:
    print("A recipe that uses potato:")
    print(my_doc)
else:
    print("No recipe found using potato.")
# Out:
# A recipe that uses potato:
# {'_id': ObjectId('6a24304f66a1f1cf734ae3a6'), 'name': 'Meal#3', 'ingredients': ['potato', 'tomato', 'olive oil', 'onion', 'garlic', 'paprika'], 'prep_time': 80}

# %% [markdown]
# ## Step 5: Update Document (Update)
# Use `find_one_and_update()` to change a field value for a specific document.

# %%
updated_doc = my_collection.find_one_and_update(
    {"ingredients": "potato"},
    {"$set": {"prep_time": 81}},
    return_document=pymongo.ReturnDocument.AFTER
)



if updated_doc:
    print("Updated recipe:")
    print(updated_doc)
else:
    print("No recipe found to update.")
# Out:
# Updated recipe:
# {'_id': ObjectId('6a24304f66a1f1cf734ae3a6'), 'name': 'Meal#3', 'ingredients': ['potato', 'tomato', 'olive oil', 'onion', 'garlic', 'paprika'], 'prep_time': 81}

# %% [markdown]
# ## Step 6: Delete Documents (Delete)
# Use `delete_many()` to remove recipes with specific names.

# %%
# Uncomment to perform deletion
delete_result = my_collection.delete_many({"$or": [{"name": "Meal#3"}, {"name": "Meal#4"}]})
print(f"Deleted {delete_result.deleted_count} documents.")
# Out:
# Deleted 2 documents.
