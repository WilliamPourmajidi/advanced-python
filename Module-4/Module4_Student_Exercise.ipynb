# %% [markdown]
# # Module 4 Practice: Descriptive Statistics and Data Summarization
#
# **In-class activity**
#
# In the lecture notebook we worked through descriptive statistics on the **Titanic** dataset. In this activity you will practice the *same* techniques on a *different* dataset: the **Penguins** dataset from Seaborn.
#
# The structure below mirrors the lecture step by step. Wherever you see a `# TODO`, that line is yours to complete. The surrounding code is provided as scaffolding so you can focus on the statistics, not the syntax.
#
# ### What you will practice
# - Loading a dataset into a pandas DataFrame and inspecting it
# - Reading dataset shape, column types, and summary statistics
# - Computing central tendency: mean, median, mode
# - Finding and handling missing values (dropping vs. imputing)
# - Measuring spread: range, IQR, variance, standard deviation
# - Measuring relationships: correlation and covariance, plus heatmaps
# - Summarizing a numeric column grouped by a category
#
# ### How to work through this
# - Run the cells **in order** from top to bottom.
# - Fill in every `# TODO` before running the cell.
# - After each result, read the short **Think about it** prompts and jot a one line answer in the markdown cell or a comment.
#
# > Tip: if a cell errors, it is almost always because an earlier `# TODO` was skipped or `df` / `df_clean` was not created yet. Re-run from the top.

# %% [markdown]
# ## 1. Load and Inspect the Penguins Dataset
#
# We will use the **penguins** dataset that ships with Seaborn (no download needed).
#
# **Your tasks**
# - Import the libraries you need.
# - Load the `'penguins'` dataset into a DataFrame called `df`.
# - Show the first few rows.

# %%
# These imports are provided for you
import pandas as pd
import seaborn as sns
import numpy as np

# TODO: load the 'penguins' dataset into a DataFrame named df
df = ____

# TODO: show the first 5 rows of df
____

# %% [markdown]
# ## 2. Dataset Overview
#
# Before any analysis, get a feel for the size and structure of the data.
#
# **Your tasks**
# - Print the **shape** (rows, columns).
# - Print the **info** (column names, data types, and non-null counts).
#
# **Think about it:** How many rows and columns are there? Which columns look numeric and which look categorical?

# %%
# TODO: show the shape of df (rows, columns)
____

# %%
# TODO: show the info() of df
# This tells you each column's type and how many non-null (non-missing) values it has
____

# %% [markdown]
# ## 3. Descriptive Statistics
#
# Use the built-in summary methods to describe the data.
#
# **Your tasks**
# - Produce summary statistics for **all** columns (numeric and categorical).
# - Compute the **mean**, **median**, and **mode** of the `body_mass_g` column.
#
# > In the lecture we used the Titanic `age` column. Here, `body_mass_g` plays the same role: a numeric column with a meaningful spread.

# %%
# TODO: describe ALL columns, not just the numeric ones
# Hint: describe() takes an include parameter
df.describe(include=____)

# %%
col = 'body_mass_g'

# TODO: print the mean of the body_mass_g column
print("Mean body mass (g):", ____)

# TODO: print the median of the body_mass_g column
print("Median body mass (g):", ____)

# TODO: print the mode of the body_mass_g column
# Hint: mode() returns a Series, so take the first element with [0]
print("Mode body mass (g):", ____)

# %% [markdown]
# ## 4. Handling Missing Values
#
# Real datasets have gaps. Penguins is no exception.
#
# **Your tasks**
# - Count the missing values in **each** column.
# - Decide how to handle the missing `body_mass_g` values.
#
# ### 4a. Find the missing values
# `df.isnull()` returns a True/False table where True means the value is missing. Chaining `.sum()` counts the True values per column.

# %%
# TODO: count missing values in each column
____

# %% [markdown]
# ### 4b. Option 1 — Drop the missing rows
#
# Dropping rows is reasonable when the number of missing values is **small** relative to the dataset and the missingness is roughly **random**.
#
# **Your tasks**
# - Create `df_clean` by dropping rows where `body_mass_g` is missing.
# - Print the row count before and after, and how many rows were removed.

# %%
# TODO: drop rows where 'body_mass_g' is missing, store the result in df_clean
# Hint: use dropna() with the subset parameter
df_clean = df.dropna(subset=[____])

# Compare size before and after
print(f"Original dataset size: {df.shape[0]} rows")
print(f"After dropping missing 'body_mass_g': {df_clean.shape[0]} rows")
# TODO: print how many rows were removed (subtract the two shapes)
print(f"Rows removed: {____}")

# %% [markdown]
# ### 4c. Option 2 — Impute instead of dropping
#
# Instead of removing rows, we can **fill** the gaps with a representative value such as the median.
#
# **Your task:** Create a new column `body_mass_imputed` on the original `df`, filling missing `body_mass_g` values with the **median**.
#
# **Think about it:** When would you prefer dropping, and when would you prefer imputing? Write one sentence as a comment.

# %%
# TODO: fill missing body_mass_g values with the MEDIAN and store in a new column
df['body_mass_imputed'] = df['body_mass_g'].fillna(____)

df.head(10)

# Your one-sentence answer (drop vs impute):
#

# %% [markdown]
# ## 5. Measures of Spread
#
# Central tendency tells you the center. Spread tells you how scattered the data is. Use the **cleaned** DataFrame (`df_clean`) so the missing values do not interfere.
#
# **Your tasks:** for the `body_mass_g` column in `df_clean`, compute the min, max, range, IQR, variance, and standard deviation.
#
# | Metric | Meaning |
# |--------|---------|
# | **Min / Max** | Smallest and largest values |
# | **Range** | Max minus Min, the total spread |
# | **IQR** | Q3 minus Q1, the middle 50% of the data |
# | **Variance** | Average squared deviation from the mean |
# | **Std Dev** | Square root of variance, the typical deviation from the mean |

# %%
col = 'body_mass_g'

print("Min:", df_clean[col].min())
print("Max:", df_clean[col].max())

# TODO: Range = max - min
print("Range:", ____)

# TODO: IQR = 75th percentile minus 25th percentile
# Hint: use the .quantile() method with 0.75 and 0.25
print("IQR:", ____)

# TODO: variance
print("Variance:", ____)

# TODO: standard deviation
print("Std Dev:", ____)

# %% [markdown]
# **Think about it:** The standard deviation is in grams, the same unit as the data, while the variance is in grams squared. Which of the two is easier to interpret directly, and why?

# %% [markdown]
# ## 6. Correlation and Covariance
#
# Now we look at **relationships between numeric columns**.
#
# - **Correlation** is scale-independent and ranges from -1 to +1.
# - **Covariance** measures joint variability but depends on the scale of the variables.
#
# **Your tasks**
# - Build the correlation matrix for the numeric columns of `df_clean`.
# - Visualize it as a heatmap.
# - Build and visualize the covariance matrix.
# - Summarize a numeric column grouped by a category.

# %%
# TODO: correlation matrix of the numeric columns in df_clean
# Hint: use .corr() with numeric_only=True
df_clean.corr(numeric_only=____)

# %% [markdown]
# **Think about it:** Which pair of measurements is most strongly correlated? Does the sign (positive or negative) match your intuition about penguin bodies?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# TODO: pass the correlation matrix into the heatmap
sns.heatmap(____, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# TODO: covariance matrix of the numeric columns in df_clean
df_clean.cov(numeric_only=____)

# %%
# TODO: heatmap of the covariance matrix
sns.heatmap(____, annot=True, cmap='YlGnBu')
plt.title('Covariance Matrix Heatmap')
plt.show()

# %% [markdown]
# ### Group summary
#
# In the lecture we computed average fare per passenger class with `groupby`. Do the same idea here: average **body mass per species**.
#
# **Your task:** group `df` by `species` and compute the mean of `body_mass_g`.

# %%
# TODO: average body_mass_g grouped by species
df.groupby(____)[____].mean()

# %% [markdown]
# ## 7. Stretch Challenges (optional)
#
# If you finish early, try these. No scaffolding this time, write the code yourself.
#
# 1. **Group by island.** Compute the mean `flipper_length_mm` for each `island`.
# 2. **Two-level group.** Compute the mean `body_mass_g` grouped by both `species` and `sex`.
# 3. **Compare imputation methods.** Add a `body_mass_mean_imputed` column using the *mean* instead of the median. Do the two imputed columns differ much? Why or why not?
# 4. **Spot the outliers.** Using the IQR rule, identify any `body_mass_g` values below `Q1 - 1.5*IQR` or above `Q3 + 1.5*IQR`.

# %%
# Space for your stretch-challenge work

# %% [markdown]
# ## Wrap-up
#
# You just reproduced the full Module 4 workflow on a brand new dataset:
#
# - Loaded and inspected the data
# - Summarized it with descriptive statistics
# - Found and handled missing values two different ways
# - Measured spread with range, IQR, variance, and standard deviation
# - Measured relationships with correlation and covariance, including heatmaps
# - Built a grouped summary
#
# The dataset changed, but the toolkit stayed the same. That is the point: these methods transfer to almost any tabular dataset you will meet.
