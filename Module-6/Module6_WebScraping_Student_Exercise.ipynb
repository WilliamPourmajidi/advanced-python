# %% [markdown]
# # Module 6: In-Class Activity - Web Scraping (Student Exercise)
# In this activity, you will scrape country data from <https://www.scrapethissite.com/pages/simple/> using `requests` and `BeautifulSoup`.
#
# You are given starter code and guided steps, but **you will complete the key parsing logic**.

# %% [markdown]
# ## Activity Goals
# By the end of this exercise, you should be able to:
# - Send HTTP requests and check response status
# - Parse HTML with BeautifulSoup
# - Extract country name, capital, and population
# - Store and summarize scraped data with pandas

# %%
# Step 1: Import required libraries
# TODO: Import requests, BeautifulSoup from bs4, and pandas as pd

# your code here

# %% [markdown]
# ## Step 2: Fetch and parse the page
# Complete the function so it requests the page and returns `soup`.
#
# Target URL: `https://www.scrapethissite.com/pages/simple/`

# %%
def get_soup():
    """Fetch the countries page and return a BeautifulSoup object."""
    url = "https://www.scrapethissite.com/pages/simple/"

    # TODO: send request to url
    # TODO: print or check the response status code
    # TODO: if status is not 200, return None
    # TODO: return BeautifulSoup(response.text, 'html.parser')

    # your code here
    pass

# %% [markdown]
# ## Step 3: Test your helper and inspect the page
# If your function works, you should see a page title and a list of country blocks.

# %%
soup = get_soup()

if soup is not None:
    print("Title:", soup.title.text.strip())
    country_blocks = soup.find_all('div', class_='country')
    print("Country blocks found:", len(country_blocks))

# %% [markdown]
# ## Step 4: Extract data from one country block
# Complete `parse_country_block` to return a dictionary with keys:
# - `Country`
# - `Capital`
# - `Population`

# %%
def parse_country_block(block):
    # TODO: extract country name
    # TODO: extract capital
    # TODO: extract population (convert to int)
    # TODO: return a dictionary with Country, Capital, Population

    # your code here
    pass

# %% [markdown]
# ## Step 5: Scrape all countries from the page
# Complete the loop to parse each country block and append each record to `all_countries`.

# %%
all_countries = []

if soup is not None:
    country_blocks = soup.find_all('div', class_='country')
    # TODO: loop through each block
    # TODO: call parse_country_block(block)
    # TODO: append parsed data to all_countries

    # your code here
    pass

print("Total countries scraped:", len(all_countries))

# %% [markdown]
# ## Step 6: Create DataFrame and inspect data
# Create a DataFrame named `df_countries` from `all_countries` and display the first 10 rows.

# %%
# TODO: create DataFrame and view top rows
# your code here

# %% [markdown]
# ## Step 7: Mini analysis tasks
# Complete the following:
# 1. Show the top 10 countries by population
# 2. Find the population of Canada
# 3. Save your dataset as `countries_activity_output.csv`

# %%
# Task 1: Top 10 countries by population
# your code here

# Task 2: Population of Canada
# your code here

# Task 3: Save CSV
# your code here

# %% [markdown]
# ## Bonus Challenge (Optional)
# 1. Add a new column called `Population_Millions`.
# 2. Show only countries with population above 50 million.
# 3. Find the capital city of the most populated country.
