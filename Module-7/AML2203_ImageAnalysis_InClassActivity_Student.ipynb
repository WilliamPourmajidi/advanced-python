# %% [markdown]
# # ImageAnalysis: In-Class Student Activity
#
# In this activity, you will practice reading, displaying, analyzing, and transforming images with Python.
#
# You will use:
# - `PIL` / `Pillow` for opening and editing images
# - `matplotlib` for displaying images and charts
# - `numpy` for working with image pixels as arrays
#
# Work through each section in order. Complete the `TODO` lines before running each cell.

# %% [markdown]
# ## Learning Goals
#
# By the end of this activity, you should be able to:
#
# 1. Load and display an image in Python.
# 2. Inspect image format, mode, size, and array shape.
# 3. Convert an image to grayscale.
# 4. Crop an image using pixel coordinates.
# 5. Split an RGB image into color channels.
# 6. Create a histogram of grayscale pixel values.
# 7. Calculate simple pixel statistics.
# 8. Highlight pixels that meet a condition.
# 9. Save a processed image.

# %% [markdown]
# ## 1. Import Libraries
#
# Run this cell first. These libraries will be used throughout the notebook.

# %%
# Import the libraries needed for image analysis.
# PIL Image opens and edits image files.
# matplotlib displays images and charts.
# numpy allows us to treat images as arrays of numbers.

# TODO: Run this cell before continuing.
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 2. Load and Display an Image
#
# The image file is in the same folder as this notebook, so we can use a relative path.

# %%
# TODO 1: Set image_path to 'main_image.jpg'
image_path = None

# TODO 2: Open the image using Image.open()
image = None

# TODO 3: Display the image using plt.imshow()
plt.figure(figsize=(8, 6))
# plt.imshow(...)
plt.axis('off')
plt.title('Original Image')
plt.show()

# %% [markdown]
# ## 3. Inspect Image Information
#
# Images have useful properties such as format, color mode, and size.
#
# Common modes:
# - `RGB`: red, green, blue color image
# - `L`: grayscale image
# - `RGBA`: red, green, blue, alpha/transparency

# %%
# TODO: Print the image format, mode, and size.
# Hint: use image.format, image.mode, and image.size

print('Image Format:', None)
print('Image Mode  :', None)
print('Image Size  :', None)

# %% [markdown]
# ## 4. Convert the Image to a NumPy Array
#
# A color image can be represented as a 3D NumPy array:
#
# `(height, width, channels)`
#
# For an RGB image, the channels are red, green, and blue.

# %%
# TODO 1: Convert the image to a NumPy array.
image_array = None

# TODO 2: Print the array shape and data type.
print('Shape of image array:', None)
print('Data type:', None)

# TODO 3: Display the first 5 rows and first 5 columns of pixel values.
# Hint: use array slicing.
# image_array[...]

# %% [markdown]
# ## 5. Convert to Grayscale
#
# Grayscale images use one intensity value per pixel instead of three color channels.
#
# The value ranges from:
# - `0`: black
# - `255`: white

# %%
# TODO 1: Convert image to grayscale using image.convert('L')
gray_image = None

# TODO 2: Display the grayscale image.
plt.figure(figsize=(8, 6))
# plt.imshow(..., cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')
plt.show()

# %% [markdown]
# ## 6. Crop the Image
#
# The `crop()` method uses a box with four values:
#
# `(left, upper, right, lower)`
#
# These values are pixel coordinates.

# %%
# TODO 1: Choose crop coordinates.
# Start with these coordinates, then experiment:
# left = 210, upper = 320, right = 480, lower = 450
crop_box = (None, None, None, None)

# TODO 2: Crop the image using image.crop(crop_box)
cropped = None

# TODO 3: Display the cropped image.
plt.figure(figsize=(8, 4))
# plt.imshow(...)
plt.axis('off')
plt.title('Cropped Image')
plt.show()

# %% [markdown]
# ## 7. Split RGB Channels
#
# An RGB image stores separate red, green, and blue intensity values for each pixel.
#
# In this step, you will split the image into its three channels and display them.

# %%
# TODO 1: Split the image into red, green, and blue channels.
# Hint: r, g, b = image.split()
r, g, b = None, None, None

# TODO 2: Display the three channels side by side.
channels = [(r, 'Red Channel'), (g, 'Green Channel'), (b, 'Blue Channel')]

plt.figure(figsize=(12, 4))
for index, (channel, title) in enumerate(channels, start=1):
    plt.subplot(1, 3, index)
    # plt.imshow(channel, cmap='gray')
    plt.axis('off')
    plt.title(title)
plt.show()

# %% [markdown]
# ## 8. Grayscale Pixel Intensity Histogram
#
# A histogram shows how often each pixel intensity appears.
#
# For grayscale images:
# - Lower values mean darker pixels.
# - Higher values mean brighter pixels.

# %%
# TODO 1: Convert gray_image to a NumPy array.
gray_array = None

# TODO 2: Flatten the 2D grayscale array into a 1D list of pixel values.
gray_flat = None

# TODO 3: Plot a histogram with 256 bins and range 0 to 255.
plt.figure(figsize=(8, 5))
# plt.hist(...)
plt.title('Pixel Intensity Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 9. Basic Pixel Statistics
#
# Mean and standard deviation can summarize image brightness and contrast.
#
# - Higher mean: brighter image/channel
# - Higher standard deviation: more variation/contrast

# %%
# TODO: Calculate the mean and standard deviation for each RGB channel.
# Hint: use np.mean(image_array, axis=(0, 1)) and np.std(image_array, axis=(0, 1))

rgb_mean = None
rgb_std = None

print('Mean pixel value (R, G, B):', rgb_mean)
print('Standard deviation (R, G, B):', rgb_std)

# %% [markdown]
# ## 10. Highlight the Most Common Grayscale Intensity
#
# In this step, you will:
#
# 1. Find the most common grayscale value.
# 2. Create a mask for pixels with that value.
# 3. Convert the grayscale image back into RGB array form.
# 4. Highlight matching pixels in red.

# %%
# TODO 1: Count how often each grayscale intensity appears.
# Hint: np.bincount works well with integer pixel values.
counts = None

# TODO 2: Find the intensity with the largest count.
most_frequent_intensity = None
print('Most frequent pixel intensity:', most_frequent_intensity)

# TODO 3: Create a mask where gray_array equals the most frequent intensity.
mask = None

# TODO 4: Stack the grayscale array into 3 channels so we can add red color.
highlighted = None

# TODO 5: Set all masked pixels to red: [255, 0, 0]
# highlighted[mask] = ...

# TODO 6: Display the highlighted image.
plt.figure(figsize=(8, 6))
# plt.imshow(...)
plt.axis('off')
plt.title('Most Common Intensity Highlighted')
plt.show()

# %% [markdown]
# ## 11. Resize, Rotate, and Save
#
# Finally, create a smaller rotated version of the original image and save it as a new file.

# %%
# TODO 1: Resize the image to 50 percent of its original width and height.
width, height = image.size
new_size = (None, None)
resized = None

# TODO 2: Rotate the resized image by 90 degrees.
rotated = None

# TODO 3: Save the final image as 'student_processed_image.jpg'.
# rotated.save(...)

# TODO 4: Display the final result.
plt.figure(figsize=(6, 6))
# plt.imshow(...)
plt.axis('off')
plt.title('Resized and Rotated Image')
plt.show()

# %% [markdown]
# ## Reflection Questions
#
# Answer these questions after completing the activity:
#
# 1. What changed when the image was converted from RGB to grayscale?
# 2. Which RGB channel appeared brightest or most detailed? Why might that happen?
# 3. What does the histogram tell you about the image brightness?
# 4. How did changing the crop coordinates affect the result?
# 5. What is one real-world use case for highlighting pixels based on intensity?
